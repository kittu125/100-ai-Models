# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/pkitt/OneDrive/Desktop/bedroom.csv")

# %%
df.isnull().sum()
# Out:
# area       0
# bedroom    1
# age        0
# price      0
# dtype: int64

# %%
df_bedroom=df.bedroom.fillna(df.bedroom.mean(),inplace=True)
# Out:
# C:\Users\pkitt\AppData\Local\Temp\ipykernel_1444\2818137361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_bedroom=df.bedroom.fillna(df.bedroom.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# area       0
# bedroom    0
# age        0
# price      0
# dtype: int64

# %%
df.final=pd.concat([df,df_bedroom],axis=1)
# Out:
# C:\Users\pkitt\AppData\Local\Temp\ipykernel_1444\3958491702.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.final=pd.concat([df,df_bedroom],axis=1)

# %%
df.final.head()
# Out:
#    area  bedroom  age   price
# 0  2600     3.00   20  550000
# 1  3000     4.00   15  565000
# 2  3200     3.75   18  610000
# 3  3600     3.00   30  595000
# 4  4000     5.00    8  760000

# %%
matrix=df.final.corr()

# %%
matrix
# Out:
#              area   bedroom       age     price
# area     1.000000  0.613769 -0.224033  0.863330
# bedroom  0.613769  1.000000 -0.893716  0.835340
# age     -0.224033 -0.893716  1.000000 -0.621277
# price    0.863330  0.835340 -0.621277  1.000000

# %%
X=df.final[['area','bedroom']]

# %%
y=df.final[["price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
fit=lr.fit(X_train,y_train)

# %%
fit.score(X_train,y_train)
# Out:
# 1.0

# %%
fit.predict([[2600,3]])
# Out:
# C:\Users\pkitt\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[550000.]])
